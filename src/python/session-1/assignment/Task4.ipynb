# %% [markdown]
# ## Encoded Message:
#
# `##$$$@!yalpstcejorp EPUVT****9887`
#
# ## Steps to Decode:
#
# 1. Extract the core part of the message: `"yalpstcejorp EPUVT"`.
#
# 2. Reverse the first word: `"yalpstcejorp"` becomes `"projectplay"`.
#
# 3. Replace shifted vowels in the second word:
#    - `"EPUVT"`: Replace `E -> A` and `U -> O` to get `"APOVT"`.
#
# 4. Final decoded message: `"projectplay APTOV"`.

# %%
message="##$$$@!yalpstcejorp EPUVT****9887"

message=message[7:-8]
print("Core Part : ",message)
message=message.replace("yalpstcejorp","projectplay")
print("Reversed message : ",message)
message=message.replace("E","A")
message=message.replace("U","O")
print("Output : ",message)
# Out:
# Core Part :  yalpstcejorp EPUVT
# Reversed message :  projectplay EPUVT
# Output :  projectplay APOVT
