# %%
print("hellow world")
'''dafdaf
khkhkhkjbl;jnljh
'''
'''
'''
# Out:
# hellow world
# '\nkhkhkhkjbl;jnljh\n'

# %%
name="adam"
age=20
course_name='python'
output=f"My name is {name} and my age is {age} and my course is {course_name}"
